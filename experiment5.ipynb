# %% [markdown]
# <a href="https://colab.research.google.com/github/pyonan/Sets-and-Dictionaries-in-Python/blob/main/experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment - 5
# ## Title: Sets and Dictionaries in Python

# %% [markdown]
# ### Sets

# %%
# Creation of Set
stationary={"pencil","pen","scale"}
print(stationary)
# Out:
# {'pencil', 'pen', 'scale'}

# %%
# Duplicates not allowed
stationary={"pencil","pen","scale","pen"}
print(stationary)
# Out:
# {'pencil', 'pen', 'scale'}

# %%
# True and 1 are considered same
stationary={"pencil","pen","scale",True, 1, False, 0}
print(stationary)
# Out:
# {False, True, 'pen', 'pencil', 'scale'}

# %%
# Set wiht strings, integers and boolean values
thisset={'ananya',23,False,42.5}
print(thisset)
# Out:
# {False, 42.5, 'ananya', 23}

# %%
# Searching in Set
stationary={"pencil","pen","scale"}
print('pencil' in stationary)
print('eraser' in stationary)
# Out:
# True
# False

# %%
# Items in sets are not replaceable, but items can be added and deleted from them
stationary={"pencil","pen","scale","pen"}
stationary.add('eraser')
stationary.remove('pen')

print(stationary)
# Out:
# {'pencil', 'scale', 'eraser'}

# %%
# Set operations
a={1,2,6,4}
b={5,4,7,6}

print('Union:', a|b)
print('Intersection:',a & b)
print('Difference:',a-b)
print('Symmetric Difference:', a^b)
# Out:
# Union: {1, 2, 4, 5, 6, 7}
# Intersection: {4, 6}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 5, 7}

# %%
# Frozen Set
f_s=frozenset({"pencil","pen","scale"})
print(f_s)
print(type(f_s))
# Out:
# frozenset({'pencil', 'pen', 'scale'})
# <class 'frozenset'>

# %%
# Adding and removing is NOT allowed in frozen set
f_s=frozenset({"pencil","pen","scale"})
f_s.add('eraser')
f_s.remove('pen')

print(f_s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4045775036.py in <cell line: 0>()
#       1 # Adding and removing is NOT allowed in frozen set
#       2 f_s=frozenset({"pencil","pen","scale"})
# ----> 3 f_s.add('eraser')
#       4 f_s.remove('pen')
#       5
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# Problem 1
student_names=['Ansh','Atharv','Sara','Shaivi','Mihika','Advik']
unique_student=set(student_names)
print('The List of Students who have registered:')
print(unique_student)
# Out:
# The List of Students who have registered:
# {'Atharv', 'Mihika', 'Shaivi', 'Sara', 'Ansh', 'Advik'}

# %%
# Problem 2
ananya={'AMT','EDP','PES','EG','Cybersecurity'}
soumya={'DEVC','EI','ERA','IAI','Cybersecurity'}
jayvee={'LA','EEEE','ECSF','FMS','Cybersecurity'}

print('The common subject is',ananya&soumya&jayvee)
# Out:
# The common subject is {'Cybersecurity'}

# %%
# Problem 3
cricket={'anmol','anant','shubhi','sara'}
football={'ansh','sara','shaivi'}
print('Both Clubs:',cricket & football)
print('Only one clubs:',cricket^football)
# Out:
# Both Clubs: {'sara'}
# Only one clubs: {'anant', 'shubhi', 'shaivi', 'anmol', 'ansh'}

# %%
# Problem 5
courses=['TS6001','FT0097','TC6007','EG003']
print('Total course',courses)
actual_courses=set(courses)
actual_courses.remove('EG003')
print('Actual Courses',actual_courses)
# Out:
# Total course ['TS6001', 'FT0097', 'TC6007', 'EG003']
# Actual Courses {'TC6007', 'TS6001', 'FT0097'}

# %%
# Problem 4
all_students={'aadi','ansh','ansh s', 'apoorba','srushti','ananya','aditi'}
present_students={'aadi','ansh','apoorba'}
print('absent students are',all_students-present_students)
# Out:
# absent students are {'ansh s', 'aditi', 'ananya', 'srushti'}

# %% [markdown]
# ###Dictionaries

# %%
# Creation of Dictionary
thisdict={
    'company':'apple',
    'product':'iphone',
    'year': 2025
}
print(thisdict)
# Out:
# {'company': 'apple', 'product': 'iphone', 'year': 2025}

# %%
# Dictionary takes latest value given to key. It doesnt allow duplicates
thisdict={
    'company':'apple',
    'product':'iphone',
    'year': 2023,
    'year':2025
}
print(thisdict)
# Out:
# {'company': 'apple', 'product': 'iphone', 'year': 2025}

# %%
# Length of key-value pair
len(thisdict)
# Out:
# 3

# %%
# Changing/ Adding key:value in dictionary
product={
    'company':'apple',
    'product':'iphone',
    'year': 2025
}
product['colour']='lavender'
x=product.values()
y=product.keys()
print(x)
print(y)
# Out:
# dict_values(['apple', 'iphone', 2025, 'lavender'])
# dict_keys(['company', 'product', 'year', 'colour'])

# %%
# print customer's name
customer={
    'name':'jayvee',
    'product':'power bank',
    'date':'30 jan'
}
print('Customer Name:',customer['name'])
# Out:
# Customer Name: jayvee

# %%
# Adding and Updating Elements
customer['product2']='bangles'
customer['name']='soumya'
print(customer)
# Out:
# {'name': 'soumya', 'product': 'power bank', 'date': '30 jan', 'product2': 'bangles'}

# %%
# Removing Elements
customer.pop('date')
print('updated details:',customer)
# Out:
# updated details: {'name': 'soumya', 'product': 'power bank', 'product2': 'bangles'}

# %%
# Problem 1
products={
    'milk':25,
    'cereal':80,
    'bread':35,
    'cheese':30,
    'nutella':285,
    'chips':30
}
print('Original Price:',products)

products['nutella']=150
print('Updated Price',products)
# Out:
# Original Price: {'milk': 25, 'cereal': 80, 'bread': 35, 'cheese': 30, 'nutella': 285, 'chips': 30}
# Updated Price {'milk': 25, 'cereal': 80, 'bread': 35, 'cheese': 30, 'nutella': 150, 'chips': 30}

# %%
# Problem 2
marks={
    'Aayushi':78,
    'Seerat':89,
    'Avani':76,
    'Kimaya':80
}
name=input('Enter student name:')
print(marks.get(name,'Student not found')) #works like if-else
# Out:
# Enter student name:ananya
# Student not found

# %%
# Problem 3
logins={
    'emp1':'emp001',
    'emp2':'emp002',
    'emp3':'emp003',
    'emp4':'emp004'
}
user_id=input('Enter user id:')
if  user_id in logins.keys():
  password=input('Enter password:')
  if password==logins[user_id]:
    print('Access Granted')
else:
  print('User not found')
# Out:
# Enter user id:emp2
# Enter password:emp002
# Access Granted

# %%
# Problem 4
maths={
    'kamya':10,
    'prakriti':9.5,
    'sharique':9,
    'hrdaya':8,
    'sainyam':4
}
topper=max(maths, key=maths.get)
print('The class topper is',topper)
# Out:
# The class topper is kamya
